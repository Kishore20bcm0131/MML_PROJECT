# %%
from pathlib import Path

import numpy as np
import pandas as pd

from rdkit import Chem
from rdkit.Chem import AllChem

import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge, Lasso, BayesianRidge
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_absolute_error, r2_score

plt.rcParams["figure.figsize"] = (6, 4)

print("Imports OK")
# Out:
# Imports OK

# %%
smiles_df = pd.read_csv("../data/processed/xyz_smiles_map.csv")
print(smiles_df.shape)
smiles_df
# Out:
# (927, 3)
#                         xyz_path  \
# 0           data\raw\xyz\1\1.xyz
# 1      data\raw\xyz\1\1CH3OH.xyz
# 2        data\raw\xyz\1\1CO2.xyz
# 3         data\raw\xyz\1\1H2.xyz
# 4       data\raw\xyz\1\1H2CO.xyz
# ..                           ...
# 922    data\raw\xyz\99\99CO2.xyz
# 923     data\raw\xyz\99\99H2.xyz
# 924   data\raw\xyz\99\99H2CO.xyz
# 925    data\raw\xyz\99\99H2O.xyz
# 926  data\raw\xyz\99\99HCOOH.xyz
#
#                                                 smiles  \
# 0    Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...
# 1    CO.Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c...
# 2    Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 922               C[Si]1(C)(Cl)OC(=O)N2CCCN3CCCN1[C]32
# 923                      C[SiH](C)(Cl)N1CCCN2CCCN[C]21
# 924                   C[Si]1(C)(Cl)OCN2CCCN3CCCN1[C]32
# 925                    C[Si](C)(O)(Cl)N1CCCN2CCCN[C]21
# 926                   C[Si](C)(Cl)N1CCCN2CCCN=C21.O=CO
#
#                                                  error
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3    RDKit could not parse SMILES: c1(c(c(c(c(c1[PH...
# 4    RDKit could not parse SMILES: c1(c(c(c(c(c1P(c...
# ..                                                 ...
# 922                                                NaN
# 923                                                NaN
# 924                                                NaN
# 925                                                NaN
# 926                                                NaN
#
# [927 rows x 3 columns]

# %%
smiles_df = smiles_df[smiles_df["smiles"].notna()].copy()
print("Rows with valid SMILES:", len(smiles_df))
smiles_df.head()
# Out:
# Rows with valid SMILES: 327
#                     xyz_path  \
# 0       data\raw\xyz\1\1.xyz
# 1  data\raw\xyz\1\1CH3OH.xyz
# 2    data\raw\xyz\1\1CO2.xyz
# 5    data\raw\xyz\1\1H2O.xyz
# 7     data\raw\xyz\10\10.xyz
#
#                                               smiles error
# 0  Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...   NaN
# 1  CO.Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c...   NaN
# 2  Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...   NaN
# 5  Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...   NaN
# 7                        Bc1ccccc1N1C(C)(C)CCCC1(C)C   NaN

# %%
energy_df = pd.read_csv("../data/raw/graphs_csv/CO2.csv")
energy_df.head()
energy_df.columns
# Out:
# Index(['FLPID', 'OLD ID', 'LA-LB distance (A)', 'CO2', 'E_CO2', 'H_CO2',
#        'G_CO2', 'E_CO2_sol', 'H_CO2_sol', 'G_CO2_sol'],
#       dtype='object')

# %%
def is_co2_xyz(path_str: str) -> bool:
    name = Path(path_str).name  # e.g. "1CO2.xyz"
    return "CO2" in name  # or name.endswith("CO2.xyz")

# 1) filter rows that are CO2 xyz files
co2_df = smiles_df[smiles_df["xyz_path"].apply(is_co2_xyz)].copy()
print("Total rows in full CSV:", len(smiles_df))
print("Rows with CO2 xyz:", len(co2_df))
co2_df
# Out:
# Total rows in full CSV: 327
# Rows with CO2 xyz: 24
#                         xyz_path  \
# 2        data\raw\xyz\1\1CO2.xyz
# 16   data\raw\xyz\103\103CO2.xyz
# 23   data\raw\xyz\104\104CO2.xyz
# 114  data\raw\xyz\120\120CO2.xyz
# 128  data\raw\xyz\123\123CO2.xyz
# 135  data\raw\xyz\124\124CO2.xyz
# 149  data\raw\xyz\126\126CO2.xyz
# 177  data\raw\xyz\130\130CO2.xyz
# 254  data\raw\xyz\140\140CO2.xyz
# 261  data\raw\xyz\141\141CO2.xyz
# 338  data\raw\xyz\157\157CO2.xyz
# 408    data\raw\xyz\24\24CO2.xyz
# 543    data\raw\xyz\41\41CO2.xyz
# 692    data\raw\xyz\66\66CO2.xyz
# 699    data\raw\xyz\67\67CO2.xyz
# 706    data\raw\xyz\68\68CO2.xyz
# 713    data\raw\xyz\69\69CO2.xyz
# 727    data\raw\xyz\70\70CO2.xyz
# 789    data\raw\xyz\79\79CO2.xyz
# 852    data\raw\xyz\88\88CO2.xyz
# 859    data\raw\xyz\89\89CO2.xyz
# 873    data\raw\xyz\90\90CO2.xyz
# 880    data\raw\xyz\91\91CO2.xyz
# 922    data\raw\xyz\99\99CO2.xyz
#
#                                                 smiles error
# 2    Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...   NaN
# 16   Cc1cc(C)c(B2OC(=O)P(c3c(C)cc(C)cc3C)c3cccc4ccc...   NaN
# 23   Cc1cccc(C)c1B1OC(=O)P(c2c(C)cccc2C)c2cccc3cccc...   NaN
# 114  CC1(C)CCCC(C)(C)N1CCCB(c1c(F)c(F)c(F)c(F)c1F)c...   NaN
# 128  CC1(C)OB(c2ccccc2P(c2ccccc2)c2ccccc2)OC1(C)C.O...   NaN
# 135    CC1(C)COB(c2ccccc2P(c2ccccc2)c2ccccc2)OC1.O=C=O   NaN
# 149           CC(C)P(c1ccccc1B1Oc2ccccc2O1)C(C)C.O=C=O   NaN
# 177  Cc1cc(C)c(B(c2cc(C)c(C)cc2C)c2ccccc2N(C)C)cc1C...   NaN
# 254  CC(C)(C)P(c1ccc([C@H]2[C@H](B(c3c(F)c(F)c(F)c(...   NaN
# 261  CC1(C)[C@@H]2CC[C@@]1(C)[C@H](N1CCCCC1)[C@H]2B...   NaN
# 338                        [CH]/C=C\C=[CH].[C][C]C=[C]   NaN
# 408  CN(CCCB(c1c(F)c(F)c(F)c(F)c1F)c1c(F)c(F)c(F)c(...   NaN
# 543         CN1C(=O)OP(F)(c2ccccc2)(c2ccccc2)c2ccccc21   NaN
# 692  CC(C)N(B(OC(=O)P(C(C)(C)C)C(C)(C)C)N(C(C)C)C(C...   NaN
# 699  CCC1=C(CC)[P](c2c(C)cc(C)cc2C)(c2c(C)cc(C)cc2C...   NaN
# 706  CC(C)(C)[P]1(C(C)(C)C)C[Si](C(F)(F)C(F)(F)F)(C...   NaN
# 713          CC(C)(C)[P]1(C(C)(C)C)C[Si](F)(F)(F)OC1=O   NaN
# 727       CC(C)(C)[P]1(C(C)(C)C)C[Si](Cl)(Cl)(Cl)OC1=O   NaN
# 789  Cc1cc(C)c(P(=O)(c2c(C)cc(C)cc2C)c2cccc3c2oc2c(...   NaN
# 852  Cc1cc(C)c([P]2(c3c(C)cc(C)cc3C)[C]([CH]c3ccccc...   NaN
# 859  Cc1cc(C)c(P(/C(=C/c2ccccc2)[Al](CC(C)(C)C)CC(C...   NaN
# 873                                  [CH2][Si](C)C.[H]   NaN
# 880  CC(C)(C)/C=C(\PC([Si](C)(C)C)[Si](C)(C)C)C(=O)...   NaN
# 922               C[Si]1(C)(Cl)OC(=O)N2CCCN3CCCN1[C]32   NaN

# %%
import pandas as pd
from pathlib import Path

smiles_df = pd.read_csv("../data/processed/xyz_smiles_map.csv")
print("Total rows in CSV:", len(smiles_df))
smiles_df.head()
# Out:
# Total rows in CSV: 927
#                     xyz_path  \
# 0       data\raw\xyz\1\1.xyz
# 1  data\raw\xyz\1\1CH3OH.xyz
# 2    data\raw\xyz\1\1CO2.xyz
# 3     data\raw\xyz\1\1H2.xyz
# 4   data\raw\xyz\1\1H2CO.xyz
#
#                                               smiles  \
# 0  Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...
# 1  CO.Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c...
# 2  Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...
# 3                                                NaN
# 4                                                NaN
#
#                                                error
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3  RDKit could not parse SMILES: c1(c(c(c(c(c1[PH...
# 4  RDKit could not parse SMILES: c1(c(c(c(c(c1P(c...

# %%
import pandas as pd
from pathlib import Path

smiles_df = pd.read_csv("../data/processed/xyz_smiles_map.csv")
print("Total rows in CSV:", len(smiles_df))

smiles_df["filename"] = smiles_df["xyz_path"].apply(lambda p: Path(p).name)

co2_mask = smiles_df["filename"].str.lower().str.contains("co2")
co2_all = smiles_df[co2_mask].copy()

print("Total CO2 xyz rows (no SMILES filter):", len(co2_all))
print("CO2 rows with non-null SMILES:", co2_all["smiles"].notna().sum())
print("CO2 rows with NULL SMILES:", co2_all["smiles"].isna().sum())

co2_all[["xyz_path", "filename", "smiles"]]
# Out:
# Total rows in CSV: 927
# Total CO2 xyz rows (no SMILES filter): 132
# CO2 rows with non-null SMILES: 24
# CO2 rows with NULL SMILES: 108
#                         xyz_path    filename  \
# 2        data\raw\xyz\1\1CO2.xyz    1CO2.xyz
# 9      data\raw\xyz\10\10CO2.xyz   10CO2.xyz
# 16   data\raw\xyz\103\103CO2.xyz  103CO2.xyz
# 23   data\raw\xyz\104\104CO2.xyz  104CO2.xyz
# 30   data\raw\xyz\105\105CO2.xyz  105CO2.xyz
# ..                           ...         ...
# 894    data\raw\xyz\95\95CO2.xyz   95CO2.xyz
# 901    data\raw\xyz\96\96CO2.xyz   96CO2.xyz
# 908    data\raw\xyz\97\97CO2.xyz   97CO2.xyz
# 915    data\raw\xyz\98\98CO2.xyz   98CO2.xyz
# 922    data\raw\xyz\99\99CO2.xyz   99CO2.xyz
#
#                                                 smiles
# 2    Cc1cc(C)c(P(c2c(C)cc(C)cc2C)c2c(F)c(F)c(B(c3c(...
# 9                                                  NaN
# 16   Cc1cc(C)c(B2OC(=O)P(c3c(C)cc(C)cc3C)c3cccc4ccc...
# 23   Cc1cccc(C)c1B1OC(=O)P(c2c(C)cccc2C)c2cccc3cccc...
# 30                                                 NaN
# ..                                                 ...
# 894                                                NaN
# 901                                                NaN
# 908                                                NaN
# 915                                                NaN
# 922               C[Si]1(C)(Cl)OC(=O)N2CCCN3CCCN1[C]32
#
# [132 rows x 3 columns]

# %%
from pathlib import Path
import py3Dmol

# point this to an actual CO2 xyz file in your repo
xyz_path = Path("../data/raw/xyz/99/99CO2.xyz")  # change 1/1CO2.xyz if needed

xyz_str = xyz_path.read_text()

view = py3Dmol.view(width=500, height=400)
view.addModel(xyz_str, "xyz")  # tell py3Dmol it's XYZ format
view.setStyle({"stick": {}})   # stick representation
view.zoomTo()

view.show()
# Out:
# <div id="3dmolviewer_1765497419153398"  style="position: relative; width: 500px; height: 400px;">
#         <p id="3dmolwarning_1765497419153398" style="background-color:#ffcccc;color:black">3Dmol.js failed to load for some reason.  Please check your browser console for error messages.<br></p>
#         </div>
# <script>
#
# var loadScriptAsync = function(uri){
#   return new Promise((resolve, reject) => {
#     //this is to ignore the existence of requirejs amd
#     var savedexports, savedmodule;
#     if (typeof exports !== 'undefined') savedexports = exports;
#     else exports = {}
#     if (typeof module !== 'undefined') savedmodule = module;
#     else module = {}
#
#     var tag = document.createElement('script');
#     tag.src = uri;
#     tag.async = true;
#     tag.onload = () => {
#         exports = savedexports;
#         module = savedmodule;
#         resolve();
#     };
#   var firstScriptTag = document.getElementsByTagName('script')[0];
#   firstScriptTag.parentNode.insertBefore(tag, firstScriptTag);
# });
# };
#
# if(typeof $3Dmolpromise === 'undefined') {
# $3Dmolpromise = null;
#   $3Dmolpromise = loadScriptAsync('https://cdn.jsdelivr.net/npm/3dmol@2.5.3/build/3Dmol-min.js');
# }
#
# var viewer_1765497419153398 = null;
# var warn = document.getElementById("3dmolwarning_1765497419153398");
# if(warn) {
#     warn.parentNode.removeChild(warn);
# }
# $3Dmolpromise.then(function() {
# viewer_1765497419153398 = $3Dmol.createViewer(document.getElementById("3dmolviewer_1765497419153398"),{backgroundColor:"white"});
# viewer_1765497419153398.zoomTo();
# 	viewer_1765497419153398.addModel("35\n\nCl   -0.8843    12.2698     6.7636 \nSi    1.1207    11.2962     6.1352 \nN     1.9818    12.5041     7.2133 \nN     3.6508    12.8198     5.6158 \nN     3.3570    14.3717     7.3349 \nC     2.9773    13.2305     6.7310 \nC     1.5382    12.8296     8.5694 \nH     2.3283    12.5474     9.2729 \nH     0.6500    12.2462     8.7836 \nC     1.2578    14.3158     8.6464 \nH     0.4963    14.5514     7.9025 \nH     0.8821    14.6051     9.6272 \nC     2.5581    15.0425     8.3677 \nH     2.3741    16.0660     8.0331 \nH     3.1702    15.0948     9.2725 \nC     0.6372     9.6834     6.9252 \nH     1.3602     8.8991     6.7104 \nH    -0.3531     9.3906     6.5787 \nH     0.5621     9.8122     8.0072 \nC     0.7755    11.8208     4.3691 \nH     0.7033    12.9091     4.3182 \nH    -0.2025    11.4393     4.0759 \nH     1.5245    11.4707     3.6586 \nC     4.5985    13.6723     4.8842 \nH     5.5998    13.2672     5.0317 \nH     4.3709    13.5797     3.8238 \nC     4.5392    15.0897     6.8711 \nH     4.4943    16.0934     7.2894 \nH     5.4464    14.6086     7.2488 \nC     4.5320    15.1060     5.3572 \nH     5.3868    15.6554     4.9646 \nH     3.6215    15.5973     5.0078 \nO     4.5673    11.1100     4.4439 \nO     2.7980    10.6748     5.7327 \nC     3.6994    11.4261     5.2140 \n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n \n","xyz");
# 	viewer_1765497419153398.setStyle({"stick": {}});
# 	viewer_1765497419153398.zoomTo();
# viewer_1765497419153398.render();
# });
# </script>

# %%
import pandas as pd

co2_smiles = pd.read_csv("../data/processed/co2_xyz_smiles_obabelonly.csv")
print("Total CO2 rows:", len(co2_smiles))
print("Non-null SMILES:", co2_smiles["smiles"].notna().sum())
print("Null SMILES:", co2_smiles["smiles"].isna().sum())

co2_smiles
# Out:
# Total CO2 rows: 132
# Non-null SMILES: 132
# Null SMILES: 0
#                         xyz_path    filename  \
# 0        data\raw\xyz\1\1CO2.xyz    1CO2.xyz
# 1      data\raw\xyz\10\10CO2.xyz   10CO2.xyz
# 2    data\raw\xyz\103\103CO2.xyz  103CO2.xyz
# 3    data\raw\xyz\104\104CO2.xyz  104CO2.xyz
# 4    data\raw\xyz\105\105CO2.xyz  105CO2.xyz
# ..                           ...         ...
# 127    data\raw\xyz\95\95CO2.xyz   95CO2.xyz
# 128    data\raw\xyz\96\96CO2.xyz   96CO2.xyz
# 129    data\raw\xyz\97\97CO2.xyz   97CO2.xyz
# 130    data\raw\xyz\98\98CO2.xyz   98CO2.xyz
# 131    data\raw\xyz\99\99CO2.xyz   99CO2.xyz
#
#                                                 smiles  error
# 0    c1(c(c(c(c(c1P(c1c(cc(cc1C)C)C)c1c(cc(cc1C)C)C...    NaN
# 1          c12ccccc1[N]1(C(CCCC1(C)C)(C)C)C(=O)O[BH2]2    NaN
# 2    P1(c2cccc3cccc(B(c4c(cc(cc4C)C)C)OC1=O)c23)c1c...    NaN
# 3    P1(c2cccc3cccc(B(c4c(cccc4C)C)OC1=O)c23)c1c(cc...    NaN
# 4    [P]1(c2c3c([B](c4c(cc(cc4C)C)C)(c4c(cc(cc4C)C)...    NaN
# ..                                                 ...    ...
# 127  [P@@H]1(/C(=C\C(C)(C)C)/[B](c2c(c(c(c(c2F)F)F)...    NaN
# 128  [P]1(c2c(c(c(c(c2F)F)F)F)F)(c2c(c(c(c(c2F)F)F)...    NaN
# 129  [N@@]12[C]3[N@](CCCN3C(=O)O[B@]32[C@H]2CCC[C@@...    NaN
# 130  [N@@]12[C]3[N@@](CCCN3C(=O)O[B]2(C2CCCCC2)C2CC...    NaN
# 131       Cl[Si]1([N@]2[C]3N(CCC[N@]3CCC2)C(=O)O1)(C)C    NaN
#
# [132 rows x 4 columns]
